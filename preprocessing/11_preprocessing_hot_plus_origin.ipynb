# %%
import pandas as pd
import csv

# %%
df1 = pd.read_csv('E:/final_ing/final_ing/Untitled Folder/200325_preprocessing_v1.csv')
df2 = pd.read_csv('E:/final_ing/final_ing/200424_preprocessing_hot.csv')

# %%
df2
# Out:
#            id                                              title  writer  \
# 0     6927971                매운 팽이버섯 조림 간단 반찬/술안주/맥주안주/소주안주 굿굿!!  냠냠간단요리
# 1     6867650                          다른 반찬이 필요없는 \n매운 어묵 비빔밥~*    밥차리라
# 2     6860267  [간단 자취요리] 미친 매운맛! 빨간오뎅 집에서 만들어 먹기! / Spicy fis...      얌무
# 3     6910384                                   매운맛 쏙 마늘 꿀조림 만들기    순수해숍
# 4     6883669                                           매운콩나물잡채    시크제이맘
# ...       ...                                                ...     ...
# 3757   387802                                      매콤 매콤한~ 빨간어묵♥    박꽃나래
# 3758   387126                                  구수하고 매콤한 사천짜장 떡볶이       센
# 3759   380726                                            매콤달콤 찜닭       센
# 3760   371267                                      ◈ 매콤하고맛있는 닭꼬지    메기맹이
# 3761   351591                                     매콤달콤 쫀득한 버펄로윙스       센
#
#       viewers  size    time level  \
# 0       16313   1.0     5.0   아무나
# ...

# %%
df1['hot']=0
df2['hot']=1

# %%
df1.columns
# Out:
# Index(['id', 'title', 'writer', 'viewers', 'size', 'time', 'level',
#        'ingredients', 'description', 'total_quantity', 'main', 'main_quantity',
#        'minor', 'minor_quantity', 'source', 'source_quantity', 'step0', 'img0',
#        'step1', 'img1', 'step2', 'img2', 'step3', 'img3', 'step4', 'img4',
#        'step5', 'img5', 'step6', 'img6', 'step7', 'img7', 'step8', 'img8',
#        'step9', 'img9', 'step10', 'img10', 'step11', 'img11', 'step12',
#        'img12', 'step13', 'img13', 'step14', 'img14', 'step15', 'img15',
#        'step16', 'img16', 'step17', 'img17', 'step18', 'img18', 'step19',
#        'img19', 'step20', 'img20', 'step21', 'img21', 'step22', 'img22',
#        'step23', 'img23', 'step24', 'img24', 'complete', 'main_db', 'minor_db',
#        'sauce_db', 'step', 'img', 'title_re', 'hot'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['id', 'title', 'writer', 'viewers', 'size', 'time', 'level',
#        'ingredients', 'description', 'total_quantity', 'main', 'main_quantity',
#        'minor', 'complete', 'minor_quantity', 'source', 'source_quantity',
#        'step0', 'img0', 'step1', 'img1', 'step2', 'img2', 'step3', 'img3',
#        'step4', 'img4', 'step5', 'img5', 'step6', 'img6', 'step7', 'img7',
#        'step8', 'img8', 'step9', 'img9', 'step10', 'img10', 'step11', 'img11',
#        'step12', 'img12', 'step13', 'img13', 'step14', 'img14', 'step15',
#        'img15', 'step16', 'img16', 'step17', 'img17', 'step18', 'img18',
#        'step19', 'img19', 'step20', 'img20', 'step21', 'img21', 'step22',
#        'img22', 'step23', 'img23', 'step24', 'img24', 'main_db', 'minor_db',
#        'sauce_db', 'step', 'img', 'title_re', 'hot'],
#       dtype='object')

# %%
df=pd.concat([df2,df1])
# Out:
# C:\coding\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df=df.drop_duplicates('id', keep='first')

# %%
df.to_csv("200425_hot_plus_origin.csv", mode='w', index=False)
