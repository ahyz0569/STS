# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("E:/final_ing/final_ing/ing/a.csv")

# %%
except_ingre = ['고추', '고춧가루','고추장', '고춧', '양파'] 
idx=[]
for i in range(3762,91558):
    ingre = df['ingredients'][i]
    for ei in except_ingre:
        if ei in ingre:
            idx.append(i)
            break

# %%
df.columns
# Out:
# Index(['id', 'title', 'ingredients', 'description', 'step', 'total', 'hot'], dtype='object')

# %%
temp=df.drop(index=idx)

# %%
temp
# Out:
#             id                                             title  \
# 0      6927971                    매운 팽이버섯 조림 간단 반찬술안주맥주안주소주안주 굿굿
# 1      6867650                             다른 반찬이 필요없는 매운 어묵 비빔밥
# 2      6860267  간단 자취요리 미친 매운맛 빨간오뎅 집에서 만들어 먹기  Spicy fish cakes
# 3      6910384                                  매운맛 쏙 마늘 꿀조림 만들기
# 4      6883669                                          매운콩나물잡채
# ...        ...                                               ...
# 91545  6844483                                          버섯리조또도오전
# 91550  6844477                                        달고 맛 있는 밤밥
# 91552  6844475                          노오븐 베이킹핫케잌 믹스로 만든 밥솥 케이크
# 91553  6844474                      부드럽고 달콤한 디저트 우유 생크림 젤리 만드는 법
# 91554  6844473                                        오리훈제 야채샐러드
#
#                                              ingredients  \
# 0                                팽이버섯 고추장 진간장 설탕 다진마늘 물
# 1       사각어묵 땡초 통마늘 고추장 굴소스 올리고당 고춧가루 후추 통깨 올리브유 맛술 참기름
# ...

# %%
for i in range(3762,43851):
    id=temp.iloc[i]['id']
    df['hot'][df['id']==id]=0
# Out:
# C:\coding\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
